# %%
from utils.metrics import get_scores_for_df

# %%
raw_kits = (
    "../results/01_coronahack_rag_openrouter_qwen_qwen-2-vl-72b-instruct_True_5.jsonl"
)
get_scores_for_df(raw_kits)
# Out:
# Accuracy: 0.5
# Precision: 0.5957818181818182
# Recall: 0.5
# F1 Score: 0.49965577096011876
# Confusion Matrix:
#  [[19  2  6]
#  [22 17  8]
#  [ 9  3 14]]

# %%
rag_kits = "../results/00_kits23_raw_openrouter_x-ai_grok-vision-beta.jsonl"
get_scores_for_df(rag_kits)
# Out:
# Accuracy: 0.5494505494505495
# Precision: 0.5237224314147391
# Recall: 0.5494505494505495
# F1 Score: 0.5323445189277032
# Confusion Matrix:
#  [[ 1  0  0  0  1]
#  [ 0  0  7  2  0]
#  [ 8  1 47  5  3]
#  [ 0  0  4  2  0]
#  [ 2  0  7  1  0]]

# %%
raw_coronahack = "results/01_coronahack_raw_anthropic_claude-3-5-sonnet-latest.jsonl"
get_scores_for_df(raw_coronahack)
# Out:
# Accuracy: 0.47
# Precision: 0.4715682465682466
# Recall: 0.47
# F1 Score: 0.45666370196341666
# Confusion Matrix:
#  [[ 6 13  8]
#  [ 5 29 13]
#  [ 2 12 12]]

# %%
rag_coronahack = "results/01_coronahack_rag_anthropic_claude-3-5-sonnet-latest.jsonl"
get_scores_for_df(rag_coronahack)
# Out:
# Accuracy: 0.76
# Precision: 0.7821679615242323
# Recall: 0.76
# F1 Score: 0.758077922077922
# Confusion Matrix:
#  [[16  7  4]
#  [ 1 40  6]
#  [ 0  6 20]]

# %%
raw_brain_tumor_classification = (
    "results/03_brain_tumor_classification_raw_anthropic_claude-3-5-sonnet-latest.jsonl"
)
get_scores_for_df(raw_brain_tumor_classification)
# Out:
# Accuracy: 0.56
# Precision: 0.6032073732718894
# Recall: 0.56
# F1 Score: 0.5622608695652174
# Confusion Matrix:
#  [[12  4  5  7]
#  [ 6 15  4  4]
#  [ 2  1 12  0]
#  [ 0  1 10 17]]

# %%
rag_brain_tumor_classification = (
    "results/03_brain_tumor_classification_rag_anthropic_claude-3-5-sonnet-latest.jsonl"
)
get_scores_for_df(rag_brain_tumor_classification)
# Out:
# Accuracy: 0.91
# Precision: 0.9187129490283322
# Recall: 0.91
# F1 Score: 0.9096558418536563
# Confusion Matrix:
#  [[26  0  2  0]
#  [ 4 23  1  1]
#  [ 1  0 14  0]
#  [ 0  0  0 28]]
